# %%
import io
import zipfile
import requests
import frontmatter

# %%
url = 'https://codeload.github.com/carmad94/DE-zoomcamp-project-2023/zip/refs/heads/main'
resp = requests.get(url)
resp.content
# Out:
# b'PK\x03\x04\n\x00\x00\x00\x00\x00\xa8)\x9bV\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1e\x00\t\x00DE-zoomcamp-project-2023-main/UT\x05\x00\x01\xdcfJdPK\x03\x04\n\x00\x00\x00\x08\x00\xa8)\x9bVf\\\x95\xd7`\x04\x00\x00I\x08\x00\x00(\x00\t\x00DE-zoomcamp-project-2023-main/.gitignoreUT\x05\x00\x01\xdcfJd\x85U\xdbn\xdc6\x10}\xd7W\x10H\x81\x02\x86E\xa1\x97\x14i\xfb\x14_\x82\xa6H\\\xa3N\xfaR\x14\x02EQ\x12\xbd\x14\x87!\xa9]+_\xdf3\xd4\xae\xed\x14\x01\xfa\xb0\xdc\xe1\xdcgtfx0f\xf7]#mX}\xd7\xea\xc9\xe8] \xebs\xaa\x0eE\xe0\xd76\xab\x07\xdb\x06Jy\x8c&\xb5\xbd\xca\xaaz!.\xd6ljMs\xb0\xce\xf4\xa2\x11\x14\xb2\x9d\xed\xe7B_\xbd{\'\x06\xf0S\xd5\xb6a\xd5\n^\xdb\xb6\xa9\xcedX\xff\xd6\xd4\xffS\x9d}\x13V\xa9\x9dJ\xa9\x82\xabKa\x1e\xb2\xf1\xc9\x92OPJ\xc4\xcc+\x9br\xb4\xdd\x92\xc1\x85\xcb\xa0\xf4N\x8d\xd6\x8f\x95\xbc]\xf3D\xbe\xea\x16\xeb\xfa\xa6\xea\xcd\xde8\n\xb5\x19\xc7\x84\x1b\xacp\xd2\xc1;R=\x18\x1b[n\x7f\xcev\xe5\xf8\xe9\xc7\xa6\n*f\xb0\xd2f\xb1W\xb1\xa9\x0e\x931\x0e\xbc`C]\xe8z6Yq\xbd\xd0\x9bT
# ...

# %%
def read_repo_data(repo_owner, repo_name):
    prefix = 'https://codeload.github.com' 
    url = f'{prefix}/{repo_owner}/{repo_name}/zip/refs/heads/main'
    resp = requests.get(url)
    
    if resp.status_code != 200:
        raise Exception(f"Failed to download repository: {resp.status_code}")

    repository_data = []
    zf = zipfile.ZipFile(io.BytesIO(resp.content))
    
    for file_info in zf.infolist():
        filename = file_info.filename
        filename_lower = filename.lower()

        if not (filename_lower.endswith('.md') 
            or filename_lower.endswith('.mdx')):
            continue
    
        try:
            with zf.open(file_info) as f_in:
                content = f_in.read().decode('utf-8', errors='ignore')
                post = frontmatter.loads(content)
                data = post.to_dict()
                data['filename'] = filename
                repository_data.append(data)
        except Exception as e:
            print(f"Error processing {filename}: {e}")
            continue
    
    zf.close()
    return repository_data

# %%
read_repo_data('carmad94', 'DE-zoomcamp-project-2023')
# Out:
# [{'content': '### Problem / Overview of the Project\nA simple project which gets the forecasted and current temperature for the cities situated in Mindanao island Philippines.  The comparison of temperatures among cities (forecasted and current) per day is then visualized in the dashboard.\n\n### Dataset\nThe dataset is created by fetching the current and forecasted data from the OpenWeather API.\n\n### Dashboard\nYou may access the dashboard using this [link](https://lookerstudio.google.com/s/oipctNcA_Ps)\n\n### Project details and Implementation\nPrefect Cloud and Docker were used for this project. Services in the Google Cloud Platform were also used and these are BigQuery, Cloud Storage, and VM Instances.  \nPrefect Cloud was used in orchestrating these processes:\n- fetching weather data from the OpenWeather API\n- flattening and enhancing the response data\n- Push it to the target Cloud Storage bucket\n- Save the data to the target BigQuery table\n\n<br/>The deployed flows used 
# ...

# %%
money_printer_turbo_repo = read_repo_data('harry0703', 'MoneyPrinterTurbo')
len(money_printer_turbo_repo)
# Out:
# 3

# %%
commaai_openpilot_repo = read_repo_data('evidentlyai', 'docs')
len(commaai_openpilot_repo)
# Out:
# 95
